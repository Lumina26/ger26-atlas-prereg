# %% [markdown]
# # ATLAS prereg tests — stub notebook
# This notebook is a placeholder for the public code release.
# **Code delivery timeline:** within 10 days of the prereg publication date (Zenodo DOI: 10.5281/zenodo.16945756).
#
# **Tests:**
# - A: Orbit residual harmonics (LS/wavelets; nuisance jet/spin)
# - B: Phase-locked light-curve microstructure (folding; matched filtering)
# - C: Isotopic/compositional clustering (Bayesian mixtures)
# - D: Polarimetric texture (residuals vs standard phase curve)
#
# > For details, see the preregistration note (Zenodo).

# %%
print("ATLAS prereg stub — code will be added within 10 days. Stay tuned.")
